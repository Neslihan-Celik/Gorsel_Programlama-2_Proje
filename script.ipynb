-- %% [markdown]
-- # [dbPersonel]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [dbPersonel]    Script Date: 7.06.2021 13:03:13 ******/
CREATE DATABASE [dbPersonel]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'dbPersonel', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\dbPersonel.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'dbPersonel_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\dbPersonel_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [dbPersonel] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [dbPersonel].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [dbPersonel] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [dbPersonel] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [dbPersonel] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [dbPersonel] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [dbPersonel] SET ARITHABORT OFF 
GO
ALTER DATABASE [dbPersonel] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [dbPersonel] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [dbPersonel] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [dbPersonel] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [dbPersonel] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [dbPersonel] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [dbPersonel] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [dbPersonel] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [dbPersonel] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [dbPersonel] SET  DISABLE_BROKER 
GO
ALTER DATABASE [dbPersonel] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [dbPersonel] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [dbPersonel] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [dbPersonel] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [dbPersonel] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [dbPersonel] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [dbPersonel] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [dbPersonel] SET RECOVERY FULL 
GO
ALTER DATABASE [dbPersonel] SET  MULTI_USER 
GO
ALTER DATABASE [dbPersonel] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [dbPersonel] SET DB_CHAINING OFF 
GO
ALTER DATABASE [dbPersonel] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [dbPersonel] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [dbPersonel] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [dbPersonel] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'dbPersonel', N'ON'
GO
ALTER DATABASE [dbPersonel] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[tblpersonel]

-- %%
USE [dbPersonel]
GO

-- %%
/****** Object:  Table [dbo].[tblpersonel]    Script Date: 7.06.2021 13:03:14 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblpersonel](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[ad] [varchar](50) NOT NULL,
	[soyad] [varchar](50) NOT NULL,
	[cinsiyet] [char](1) NOT NULL,
	[tel] [varchar](11) NULL,
	[tc] [varchar](11) NULL,
	[dtarihi] [date] NULL,
	[gorev] [varchar](30) NULL,
	[gorevYeri] [varchar](30) NULL,
	[foto] [varchar](50) NULL,
	[istarih] [date] NULL,
	[egitim] [varchar](25) NULL,
	[maas] [int] NULL,
	[yetki] [int] NULL,
	[kadi] [varchar](25) NULL,
	[sifre] [varchar](25) NULL,
	[mail] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbPersonel]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [dbPersonel] SET  READ_WRITE 
GO
